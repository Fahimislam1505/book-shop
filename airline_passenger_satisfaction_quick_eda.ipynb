# %% [markdown]
# <a href="https://colab.research.google.com/github/Fahimislam1505/book-shop/blob/main/airline_passenger_satisfaction_quick_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # Load data

# %%
df = pd.read_csv('/content/drive/MyDrive/xm/PR Lab/airline_passenger_satisfaction.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129880.000000
# mean       15.091129                                3.057599
# std        38.465650                                1.526741
# min         0.000000                                0.000000
# ...

# %% [markdown]
# # Data vis
#
# How old are the passengers ?

# %%
chart = sns.countplot(x="Age", data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %% [markdown]
# Let's look at the genders

# %%
chart = sns.countplot(x="Gender", data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %% [markdown]
# There are more or less the same amount of male and female in this dataset.
#
# Type of airline customer (First-time/Returning) :

# %%
chart = sns.countplot(x="Customer Type", data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %% [markdown]
# Purpose of the flight ?

# %%
chart = sns.countplot(x="Type of Travel", data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
chart = sns.countplot(x="Class", data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %% [markdown]
# What is the distance traveled ?

# %%
chart = sns.countplot(x="Flight Distance", data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
sns.barplot(x="Gender", y="In-flight Wifi Service", data=df)

# %%
sns.barplot(y="Flight Distance", x="In-flight Wifi Service", data=df)

# %%
g = sns.jointplot(
    data=df,
    x="Flight Distance", y="In-flight Wifi Service", hue="Gender",
    kind="kde",
)

# %%
sns.pairplot(df, hue="Gender")
